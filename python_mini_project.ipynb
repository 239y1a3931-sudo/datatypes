# %% [markdown]
# <a href="https://colab.research.google.com/github/239y1a3931-sudo/datatypes/blob/main/python_mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT TITLE**
#
# **STUDENT PERFOMANCE ANALYSIS**

# %%
# !pip install numpy pandas matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# =====================================
# MINI PROJECT
# Student Marks Analysis
# Using NumPy, Pandas, Matplotlib
# =====================================

# STEP 1: Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# STEP 2: Upload File

from google.colab import files
uploaded = files.upload()


# STEP 3: Load Dataset

df = pd.read_csv('Simple 100 Student Marks 1.csv')

# Display first 5 rows
print(df.head())


# =====================================
# PANDAS OPERATIONS
# =====================================

print("\nDataset Shape:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nStatistical Summary:")
print(df.describe())


# =====================================
# NUMPY OPERATIONS
# =====================================

maths = np.array(df['maths_marks'])

print("\nAverage Maths Marks:", np.mean(maths))
print("Highest Maths Marks:", np.max(maths))
print("Lowest Maths Marks:", np.min(maths))
print("Standard Deviation:", np.std(maths))


# =====================================
# GRAPH 1 : LINE PLOT
# =====================================

plt.figure(figsize=(10,5))

plt.plot(df['maths_marks'],marker="*",color="#7856")

plt.title(" Marks Line Plot")
plt.xlabel("Student Index")
plt.ylabel("Maths Marks")

plt.show()


# =====================================
# GRAPH 2 : BAR PLOT
# =====================================

plt.figure(figsize=(12,5))

plt.bar(df['student_name'], df['science_marks'])

plt.title("Marks Bar Plot")
plt.xlabel("Student Name")
plt.ylabel("Science Marks")

plt.xticks(rotation=90)

plt.show()


# =====================================
# EXTRA ANALYSIS
# =====================================

average_total = (
    df['maths_marks'] +
    df['science_marks'] +
    df['english_marks'] +
    df['social_studies_marks'] +
    df['Hindi_marks']
) / 5

print("\nAverage Total Marks of Students:")
print(average_total.head())


# Pass/Fail Analysis

passed_students = np.sum(average_total >= 40)
failed_students = np.sum(average_total < 40)

print("\nPassed Students:", passed_students)
print("Failed Students:", failed_students)
# Out:
#      <input type="file" id="files-facbfb4c-72d5-460f-9891-6d296d109b6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-facbfb4c-72d5-460f-9891-6d296d109b6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
